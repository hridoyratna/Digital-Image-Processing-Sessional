# %% [markdown]
# 1. Mount Drive
# 2. Read operation
# 3. write operation
# 4. Save
# 5. Intensity Histrogram graph

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2

img_path = "/content/drive/MyDrive/Images/images.webp"
img = cv2.imread(img_path)

print(img.shape)
# Out:
# (480, 640, 3)

# %%
from PIL import Image

img_pil = Image.open(img_path)
img_pil
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=640x480>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
resized = cv2.resize(gray, (256, 256))

# %%
blur = cv2.GaussianBlur(resized, (5,5), 0)

# %%
import matplotlib.pyplot as plt

plt.imshow(blur, cmap='gray')
plt.title("Processed Image")
plt.axis('off')
plt.show()

# %%
import os

save_path = "/content/drive/MyDrive/processed_image.png"
cv2.imwrite(save_path, blur)

print("Image saved at:", save_path)
# Out:
# Image saved at: /content/drive/MyDrive/processed_image.png

# %%
if os.path.exists(save_path):
    print("File exists")
else:
    print("File not found")
# Out:
# File exists

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.hist(blur.ravel(), bins=256, range=[0, 256], color='blue', alpha=0.7)
plt.title('Distribution of Pixel Intensities')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()
